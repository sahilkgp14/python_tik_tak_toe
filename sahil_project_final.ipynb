# %% [markdown]
# <a href="https://colab.research.google.com/github/sahilkgp14/python_tik_tak_toe/blob/main/sahil_project_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/content/drive/MyDrive/kodeing kgp/Top10VideoGameStocks.csv")

# %%
df.head()
# Out:
#          Date                         Company Ticker Symbol Currency  \
# 0  2000-01-01  Sony Interactive Entertainment          SONY      JPY
# 1  2000-02-01  Sony Interactive Entertainment          SONY      JPY
# 2  2000-03-01  Sony Interactive Entertainment          SONY      JPY
# 3  2000-04-01  Sony Interactive Entertainment          SONY      JPY
# 4  2000-05-01  Sony Interactive Entertainment          SONY      JPY
#
#         Open       High        Low      Close  Adj Close     Volume
# 0  28.525000  29.168751  20.850000  25.299999  14.535083  147012000
# 1  25.293751  31.475000  25.000000  31.350000  18.010864   67437000
# 2  30.100000  31.299999  21.700001  28.012501  16.093437  112674000
# 3  28.250000  28.250000  22.312500  22.562500  12.974537   74071000
# 4  22.700001  23.481251  17.750000  18.237499  10.487453   65035500

# %%
jpy_to_inr=0.56
sek_to_inr=7.74
hkd_to_inr=10.88
usd_to_inr=84.67
df.head()
# Out:
#          Date                         Company Ticker Symbol Currency  \
# 0  2000-01-01  Sony Interactive Entertainment          SONY      JPY
# 1  2000-02-01  Sony Interactive Entertainment          SONY      JPY
# 2  2000-03-01  Sony Interactive Entertainment          SONY      JPY
# 3  2000-04-01  Sony Interactive Entertainment          SONY      JPY
# 4  2000-05-01  Sony Interactive Entertainment          SONY      JPY
#
#         Open       High        Low      Close  Adj Close     Volume
# 0  28.525000  29.168751  20.850000  25.299999  14.535083  147012000
# 1  25.293751  31.475000  25.000000  31.350000  18.010864   67437000
# 2  30.100000  31.299999  21.700001  28.012501  16.093437  112674000
# 3  28.250000  28.250000  22.312500  22.562500  12.974537   74071000
# 4  22.700001  23.481251  17.750000  18.237499  10.487453   65035500

# %%
convert_={'Open' : float}
df=df.astype(convert_)
print(df['Open'].dtypes)
df['Open'] = np.where(df['Currency'] == 'USD', df['Open'] * usd_to_inr, df['Open'])
df['High'] = np.where(df['Currency'] == 'USD', df['High'] * usd_to_inr, df['High'])
df['Low'] = np.where(df['Currency'] == 'USD', df['Low'] * usd_to_inr, df['Low'])
df['Close'] = np.where(df['Currency'] == 'USD', df['Close'] * usd_to_inr, df['Close'])

df['Open'] = np.where(df['Currency'] == 'JPY', df['Open'] * jpy_to_inr, df['Open'])
df['High'] = np.where(df['Currency'] == 'JPY', df['High'] * jpy_to_inr, df['High'])
df['Low'] = np.where(df['Currency'] == 'JPY', df['Low'] * jpy_to_inr, df['Low'])
df['Close'] = np.where(df['Currency'] == 'JPY', df['Close'] * jpy_to_inr, df['Close'])

df['Open'] = np.where(df['Currency'] == 'SEK', df['Open'] * sek_to_inr, df['Open'])
df['High'] = np.where(df['Currency'] == 'SEK', df['High'] * sek_to_inr, df['High'])
df['Low'] = np.where(df['Currency'] == 'SEK', df['Low'] * sek_to_inr, df['Low'])
df['Close'] = np.where(df['Currency'] == 'SEK', df['Close'] * sek_to_inr, df['Close'])

df['Open'] = np.where(df['Currency'] == 'HKD', df['Open'] * hkd_to_inr, df['Open'])
df['High'] = np.where(df['Currency'] == 'HKD', df['High'] * hkd_to_inr, df['High'])
df['Low'] = np.where(df['Currency'] == 'HKD', df['Low'] * hkd_to_inr, df['Low'])
df['Close'] = np.where(df['Close']== 'HKD', df['Close']* hkd_to_inr, df['Close'])

df['Currency'] = 'INR'

df.head()
# Out:
# float64
#          Date                         Company Ticker Symbol Currency     Open  \
# 0  2000-01-01  Sony Interactive Entertainment          SONY      INR  15.9740
# 1  2000-02-01  Sony Interactive Entertainment          SONY      INR  14.1645
# 2  2000-03-01  Sony Interactive Entertainment          SONY      INR  16.8560
# 3  2000-04-01  Sony Interactive Entertainment          SONY      INR  15.8200
# 4  2000-05-01  Sony Interactive Entertainment          SONY      INR  12.7120
#
#       High     Low   Close  Adj Close     Volume
# 0  16.3345  11.676  14.168  14.535083  147012000
# 1  17.6260  14.000  17.556  18.010864   67437000
# 2  17.5280  12.152  15.687  16.093437  112674000
# 3  15.8200  12.495  12.635  12.974537   74071000
# 4  13.1495   9.940  10.213  10.487453   65035500

# %%
df=df.drop(columns=['Currency','Adj Close'])
df.head()
# Out:
#          Date                         Company Ticker Symbol     Open     High  \
# 0  2000-01-01  Sony Interactive Entertainment          SONY  15.9740  16.3345
# 1  2000-02-01  Sony Interactive Entertainment          SONY  14.1645  17.6260
# 2  2000-03-01  Sony Interactive Entertainment          SONY  16.8560  17.5280
# 3  2000-04-01  Sony Interactive Entertainment          SONY  15.8200  15.8200
# 4  2000-05-01  Sony Interactive Entertainment          SONY  12.7120  13.1495
#
#       Low   Close     Volume
# 0  11.676  14.168  147012000
# 1  14.000  17.556   67437000
# 2  12.152  15.687  112674000
# 3  12.495  12.635   74071000
# 4   9.940  10.213   65035500

# %%
sony_db = df[df["Company"] == "Sony Interactive Entertainment"]
sony_db.head()
max_open = sony_db["Open"].max()
max_close= sony_db['Close'].max()
max_high= sony_db['High'].max()
max_low= sony_db['Low'].max()

sony_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
sony_array = np.array([sony_dict])

sony_array
# Out:
# array([{'Max Open': 16.856000213623048, 'Max High': 17.626000213623048, 'Max Low': 14.000000000000002, 'Max Close': 17.556000213623047}],
#       dtype=object)

# %%
tencent_db = df[df["Company"] == "Tencent Interactive Entertainment"]
max_open = tencent_db["Open"].max()
max_close= tencent_db['Close'].max()
max_high= tencent_db['High'].max()
max_low= tencent_db['Low'].max()

tencent_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
tencent_array = np.array([tencent_dict])

tencent_array
# Out:
# array([{'Max Open': 7000.79921875, 'Max High': 7778.108281250001, 'Max Low': 6644.7415234375, 'Max Close': 628.2451782226562}],
#       dtype=object)

# %%
msft_db = df[df["Company"] == "Microsoft Gaming"]
max_open = msft_db["Open"].max()
max_close= msft_db['Close'].max()
max_high= msft_db['High'].max()
max_low= msft_db['Low'].max()

msft_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
msft_array = np.array([msft_dict])

msft_array
# Out:
# array([{'Max Open': 3216447.559327695, 'Max High': 3357605.362071158, 'Max Low': 2955137.097410379, 'Max Close': 3204188.615367316}],
#       dtype=object)

# %%
ntdo_db = df[df["Company"] == "Nintendo"]
ntdo_db.head()
max_open = ntdo_db["Open"].max()
max_close= ntdo_db['Close'].max()
max_high= ntdo_db['High'].max()
max_low= ntdo_db['Low'].max()

ntdo_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
ntdo_array = np.array([ntdo_dict])

ntdo_array
# Out:
# array([{'Max Open': 114417.38231747599, 'Max High': 118360.33857985592, 'Max Low': 104251.72611111528, 'Max Close': 115449.71998194237}],
#       dtype=object)

# %%
ntez_db = df[df["Company"] == "NetEase Games"]
ntez_db.head()
max_open = ntez_db["Open"].max()
max_close= ntez_db['Close'].max()
max_high= ntez_db['High'].max()
max_low= ntez_db['Low'].max()

ntez_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
ntez_array = np.array([ntez_dict])

ntez_array
# Out:
# array([{'Max Open': 851534.8683907685, 'Max High': 963012.9786638473, 'Max Low': 763929.570881537, 'Max Close': 845441.2217648078}],
#       dtype=object)

# %%
ea_db = df[df["Company"] == "Electronic Arts"]
ea_db.head()
max_open = ea_db["Open"].max()
max_close= ea_db['Close'].max()
max_high= ea_db['High'].max()
max_low= ea_db['Low'].max()

ea_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
ea_array = np.array([ea_dict])

ea_array
# Out:
# array([{'Max Open': 1087538.6282519212, 'Max High': 1100514.516858458, 'Max Low': 1033412.5891788421, 'Max Close': 1088398.9837053895}],
#       dtype=object)

# %%
tti_db = df[df["Company"] == "Take-Two Interactive"]
tti_db.head()
max_open = tti_db["Open"].max()
max_close= tti_db['Close'].max()
max_high= tti_db['High'].max()
max_low= tti_db['Low'].max()

tti_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
tti_array = np.array([tti_dict])

tti_array
# Out:
# array([{'Max Open': 1495957.0740361528, 'Max High': 1540691.7289526945, 'Max Low': 1375087.5796065365, 'Max Close': 1489648.3111992264}],
#       dtype=object)

# %%
EmbG_db = df[df["Company"] == "Embracer Group"]
EmbG_db.head()
max_open = EmbG_db["Open"].max()
max_close= EmbG_db['Close'].max()
max_high= EmbG_db['High'].max()
max_low= EmbG_db['Low'].max()

EmbG_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
EmbG_array = np.array([EmbG_dict])

EmbG_array
# Out:
# array([{'Max Open': 1010.07, 'Max High': 1042.5779763793946, 'Max Low': 923.7689881896973, 'Max Close': 1008.5220236206055}],
#       dtype=object)

# %%
rbc_db = df[df["Company"] == "Roblox Corporation"]
rbc_db.head()
max_open = rbc_db["Open"].max()
max_close= rbc_db['Close'].max()
max_high= rbc_db['High'].max()
max_low= rbc_db['Low'].max()

rbc_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
rbc_array = np.array([rbc_dict])

rbc_array
# Out:
# array([{'Max Open': 918636.7960703842, 'Max High': 1015131.7039961579, 'Max Low': 668653.4360371132, 'Max Close': 904012.0113509606}],
#       dtype=object)

# %%
ptk_db = df[df["Company"] == "Playtika"]
ptk_db.head()
max_open = ptk_db["Open"].max()
max_close= ptk_db['Close'].max()
max_high= ptk_db['High'].max()
max_low= ptk_db['Low'].max()

ptk_dict = {
    'Max Open': max_open,
    'Max High': max_high,
    'Max Low': max_low,
    'Max Close': max_close
}
ptk_array = np.array([ptk_dict])

ptk_array
# Out:
# array([{'Max Open': 216288.99905995198, 'Max High': 251560.52339490395, 'Max Low': 204388.44537985593, 'Max Close': 213278.014775}],
#       dtype=object)

# %%
df['Profit']= df['Open']-df['Close']
df['Total Profit'] = df['Profit']*df['Volume']
df.head()
# Out:
#          Date                         Company Ticker Symbol     Open     High  \
# 0  2000-01-01  Sony Interactive Entertainment          SONY  15.9740  16.3345
# 1  2000-02-01  Sony Interactive Entertainment          SONY  14.1645  17.6260
# 2  2000-03-01  Sony Interactive Entertainment          SONY  16.8560  17.5280
# 3  2000-04-01  Sony Interactive Entertainment          SONY  15.8200  15.8200
# 4  2000-05-01  Sony Interactive Entertainment          SONY  12.7120  13.1495
#
#       Low   Close     Volume    Profit  Total Profit
# 0  11.676  14.168  147012000  1.806000  2.655037e+08
# 1  14.000  17.556   67437000 -3.391500 -2.287126e+08
# 2  12.152  15.687  112674000  1.169000  1.317159e+08
# 3  12.495  12.635   74071000  3.185000  2.359161e+08
# 4   9.940  10.213   65035500  2.499001  1.625238e+08

# %%
monthly_profit = df.groupby(['Company', 'Date'])['Total Profit'].sum().reset_index()
plt.figure(figsize=(36, 12))
for company in monthly_profit['Company'].unique():
    company_data = monthly_profit[monthly_profit['Company'] == company]
    plt.plot(company_data['Date'], company_data['Total Profit'], label=company)

plt.xlabel('Month')
plt.ylabel('Total Profit')
plt.title('Total Profit per Company per Month')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()
